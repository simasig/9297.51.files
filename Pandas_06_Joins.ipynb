# %%
import pandas as pd

# %%
products = pd.read_csv('data/Products.csv')
cat = pd.read_csv('data/Categories.csv')

# %%
products.head()
# Out:
#    ProductID                   ProductName  UnitPrice  CategoryID       Date1  \
# 0          1                          Chai      18.00           1  05/12/2022
# 1          2                         Chang      19.00           1  06/12/2022
# 2          3                 Aniseed Syrup      10.00           2  07/12/2022
# 3          4  Chef Anton's Cajun Seasoning      22.00           2  08/12/2022
# 4          5        Chef Anton's Gumbo Mix      21.35           2  09/12/2022
#
#         Date2
# 0  15/12/2022
# 1  16/12/2022
# 2  17/12/2022
# 3  18/12/2022
# 4  19/12/2022

# %%
cat.head()
# Out:
#    CategoryID    CategoryName  \
# 0           1       Beverages
# 1           2      Condiments
# 2           3     Confections
# 3           4  Dairy Products
# 4           5  Grains/Cereals
#
#                                          Description
# 0        Soft drinks, coffees, teas, beers, and ales
# 1  Sweet and savory sauces, relishes, spreads, an...
# 2                Desserts, candies, and sweet breads
# 3                                            Cheeses
# 4                Breads, crackers, pasta, and cereal

# %%
products.merge(cat)
# Out:
#     ProductID                      ProductName  UnitPrice  CategoryID  \
# 0           1                             Chai      18.00           1
# 1           2                            Chang      19.00           1
# 2           3                    Aniseed Syrup      10.00           2
# 3           4     Chef Anton's Cajun Seasoning      22.00           2
# 4           5           Chef Anton's Gumbo Mix      21.35           2
# ..        ...                              ...        ...         ...
# 72         73                       Rad Kaviar      15.00           8
# 73         74                    Longlife Tofu      10.00           7
# 74         75             Rhanbrau Klosterbier       7.75           1
# 75         76                     Lakkalikaari      18.00           1
# 76         77  Original Frankfurter grane Soae      13.00           2
#
#          Date1       Date2 CategoryName  \
# 0   05/12/2022  15/12/2022    Beverages
# 1   06/12/2022  16/12/2022    Beverages
# 2   07/12/2022  17/12/2022   Condiments
# 3   08/12/2022  18/12/2022   Condiments
# 4   09/12/2022  19/12/2022   Condiments
# ..         ...         ...          ...
# 72  27/02/2023  25/02/2023      Seafood
# 73  28/02/2023  26/02/2023      Produce
# 74  01/03/2023  27/02/2023    Beverages
# 75  02/03/2023  28/02/2023    Beverages
# 76  03/03/2023  01/03/2023   Condiments
#
#                                           Description
# 0         Soft drinks, coffees, teas, beers, and ales
# 1         Soft drinks, coffees, teas, beers, and ales
# 2   Sweet and savory sauces, relishes, spreads, an...
# 3   Sweet and savory sauces, relishes, spreads, an...
# 4   Sweet and savory sauces, relishes, spreads, an...
# ..                                                ...
# 72                                   Seaweed and fish
# 73                          Dried fruit and bean curd
# 74        Soft drinks, coffees, teas, beers, and ales
# 75        Soft drinks, coffees, teas, beers, and ales
# 76  Sweet and savory sauces, relishes, spreads, an...
#
# [77 rows x 8 columns]

# %%
cat.merge(products)
# Out:
#     CategoryID CategoryName                                  Description  \
# 0            1    Beverages  Soft drinks, coffees, teas, beers, and ales
# 1            1    Beverages  Soft drinks, coffees, teas, beers, and ales
# 2            1    Beverages  Soft drinks, coffees, teas, beers, and ales
# 3            1    Beverages  Soft drinks, coffees, teas, beers, and ales
# 4            1    Beverages  Soft drinks, coffees, teas, beers, and ales
# ..         ...          ...                                          ...
# 72           8      Seafood                             Seaweed and fish
# 73           8      Seafood                             Seaweed and fish
# 74           8      Seafood                             Seaweed and fish
# 75           8      Seafood                             Seaweed and fish
# 76           8      Seafood                             Seaweed and fish
#
#     ProductID                      ProductName  UnitPrice       Date1  \
# 0           1                             Chai      18.00  05/12/2022
# 1           2                            Chang      19.00  06/12/2022
# 2          24               Guarana Fantastica       4.50  01/01/2023
# 3          34                    Sasquatch Ale      14.00  12/01/2023
# 4          35                   Steeleye Stout      18.00  13/01/2023
# ..        ...                              ...        ...         ...
# 72         41  Jack's New England Clam Chowder       9.65  20/01/2023
# 73         45                      Rogede sild       9.50  25/01/2023
# 74         46                        Spegesild      12.00  26/01/2023
# 75         58           Escargots de Bourgogne      13.25  09/02/2023
# 76         73                       Rad Kaviar      15.00  27/02/2023
#
#          Date2
# 0   15/12/2022
# 1   16/12/2022
# 2   07/01/2023
# 3   17/01/2023
# 4   18/01/2023
# ..         ...
# 72  24/01/2023
# 73  28/01/2023
# 74  29/01/2023
# 75  10/02/2023
# 76  25/02/2023
#
# [77 rows x 8 columns]

# %%
mrg = pd.merge(products,
               cat,
               on = 'CategoryID',
              how='inner')

# %%
mrg.head()
# Out:
#    ProductID                   ProductName  UnitPrice  CategoryID       Date1  \
# 0          1                          Chai      18.00           1  05/12/2022
# 1          2                         Chang      19.00           1  06/12/2022
# 2          3                 Aniseed Syrup      10.00           2  07/12/2022
# 3          4  Chef Anton's Cajun Seasoning      22.00           2  08/12/2022
# 4          5        Chef Anton's Gumbo Mix      21.35           2  09/12/2022
#
#         Date2 CategoryName                                        Description
# 0  15/12/2022    Beverages        Soft drinks, coffees, teas, beers, and ales
# 1  16/12/2022    Beverages        Soft drinks, coffees, teas, beers, and ales
# 2  17/12/2022   Condiments  Sweet and savory sauces, relishes, spreads, an...
# 3  18/12/2022   Condiments  Sweet and savory sauces, relishes, spreads, an...
# 4  19/12/2022   Condiments  Sweet and savory sauces, relishes, spreads, an...

# %%
mrg[['ProductID','ProductName','CategoryID','CategoryName']].head()
# Out:
#    ProductID                   ProductName  CategoryID CategoryName
# 0          1                          Chai           1    Beverages
# 1          2                         Chang           1    Beverages
# 2          3                 Aniseed Syrup           2   Condiments
# 3          4  Chef Anton's Cajun Seasoning           2   Condiments
# 4          5        Chef Anton's Gumbo Mix           2   Condiments

# %%
mrg.count()
# Out:
# ProductID       77
# ProductName     77
# UnitPrice       77
# CategoryID      77
# Date1           77
# Date2           77
# CategoryName    77
# Description     77
# dtype: int64

# %%
mrg = pd.merge(products
               ,cat
               ,on = 'CategoryID')

# %%
mrg.head()
# Out:
#    ProductID                   ProductName  UnitPrice  CategoryID       Date1  \
# 0          1                          Chai      18.00           1  05/12/2022
# 1          2                         Chang      19.00           1  06/12/2022
# 2          3                 Aniseed Syrup      10.00           2  07/12/2022
# 3          4  Chef Anton's Cajun Seasoning      22.00           2  08/12/2022
# 4          5        Chef Anton's Gumbo Mix      21.35           2  09/12/2022
#
#         Date2 CategoryName                                        Description
# 0  15/12/2022    Beverages        Soft drinks, coffees, teas, beers, and ales
# 1  16/12/2022    Beverages        Soft drinks, coffees, teas, beers, and ales
# 2  17/12/2022   Condiments  Sweet and savory sauces, relishes, spreads, an...
# 3  18/12/2022   Condiments  Sweet and savory sauces, relishes, spreads, an...
# 4  19/12/2022   Condiments  Sweet and savory sauces, relishes, spreads, an...

# %%
mrg.count()
# Out:
# ProductID       77
# ProductName     77
# UnitPrice       77
# CategoryID      77
# Date1           77
# Date2           77
# CategoryName    77
# Description     77
# dtype: int64

# %%
products.count()
# Out:
# ProductID      77
# ProductName    77
# UnitPrice      77
# CategoryID     77
# Date1          77
# Date2          77
# dtype: int64

# %%
cat.count()
# Out:
# CategoryID      9
# CategoryName    9
# Description     8
# dtype: int64

# %%
mrg = pd.merge(products,
               cat,
               on = 'CategoryID',
              how='left')

# %%
mrg.count()
# Out:
# ProductID       77
# ProductName     77
# UnitPrice       77
# CategoryID      77
# Date1           77
# Date2           77
# CategoryName    77
# Description     77
# dtype: int64

# %%
mrg.head(70)

# %%
mrg = pd.merge(products,
               cat,
               on = 'CategoryID',
              how='right')

# %%
mrg.count()
# Out:
# ProductID       77
# ProductName     77
# UnitPrice       77
# CategoryID      78
# Date1           77
# Date2           77
# CategoryName    78
# Description     77
# dtype: int64

# %%
mrg.head(80)
# Out:
#     ProductID             ProductName  UnitPrice  CategoryID       Date1  \
# 0         1.0                    Chai      18.00           1  05/12/2022
# 1         2.0                   Chang      19.00           1  06/12/2022
# 2        24.0      Guarana Fantastica       4.50           1  01/01/2023
# 3        34.0           Sasquatch Ale      14.00           1  12/01/2023
# 4        35.0          Steeleye Stout      18.00           1  13/01/2023
# ..        ...                     ...        ...         ...         ...
# 73       45.0             Rogede sild       9.50           8  25/01/2023
# 74       46.0               Spegesild      12.00           8  26/01/2023
# 75       58.0  Escargots de Bourgogne      13.25           8  09/02/2023
# 76       73.0              Rad Kaviar      15.00           8  27/02/2023
# 77        NaN                     NaN        NaN           9         NaN
#
#          Date2          CategoryName  \
# 0   15/12/2022             Beverages
# 1   16/12/2022             Beverages
# 2   07/01/2023             Beverages
# 3   17/01/2023             Beverages
# 4   18/01/2023             Beverages
# ..         ...                   ...
# 73  28/01/2023               Seafood
# 74  29/01/2023               Seafood
# 75  10/02/2023               Seafood
# 76  25/02/2023               Seafood
# 77         NaN  Fruit and vegetables
#
#                                     Description
# 0   Soft drinks, coffees, teas, beers, and ales
# 1   Soft drinks, coffees, teas, beers, and ales
# 2   Soft drinks, coffees, teas, beers, and ales
# 3   Soft drinks, coffees, teas, beers, and ales
# 4   Soft drinks, coffees, teas, beers, and ales
# ..                                          ...
# 73                             Seaweed and fish
# 74                             Seaweed and fish
# 75                             Seaweed and fish
# 76                             Seaweed and fish
# 77                                          NaN
#
# [78 rows x 8 columns]

# %%
#outer -- full join
mrg = pd.merge(products,
               cat,
               on = 'CategoryID',
              how='outer')

# %%
mrg.count()
# Out:
# ProductID       77
# ProductName     77
# UnitPrice       77
# CategoryID      78
# Date1           77
# Date2           77
# CategoryName    78
# Description     77
# dtype: int64

# %%
mrg.head(80)
# Out:
#     ProductID             ProductName  UnitPrice  CategoryID       Date1  \
# 0         1.0                    Chai      18.00           1  05/12/2022
# 1         2.0                   Chang      19.00           1  06/12/2022
# 2        24.0      Guarana Fantastica       4.50           1  01/01/2023
# 3        34.0           Sasquatch Ale      14.00           1  12/01/2023
# 4        35.0          Steeleye Stout      18.00           1  13/01/2023
# ..        ...                     ...        ...         ...         ...
# 73       45.0             Rogede sild       9.50           8  25/01/2023
# 74       46.0               Spegesild      12.00           8  26/01/2023
# 75       58.0  Escargots de Bourgogne      13.25           8  09/02/2023
# 76       73.0              Rad Kaviar      15.00           8  27/02/2023
# 77        NaN                     NaN        NaN           9         NaN
#
#          Date2          CategoryName  \
# 0   15/12/2022             Beverages
# 1   16/12/2022             Beverages
# 2   07/01/2023             Beverages
# 3   17/01/2023             Beverages
# 4   18/01/2023             Beverages
# ..         ...                   ...
# 73  28/01/2023               Seafood
# 74  29/01/2023               Seafood
# 75  10/02/2023               Seafood
# 76  25/02/2023               Seafood
# 77         NaN  Fruit and vegetables
#
#                                     Description
# 0   Soft drinks, coffees, teas, beers, and ales
# 1   Soft drinks, coffees, teas, beers, and ales
# 2   Soft drinks, coffees, teas, beers, and ales
# 3   Soft drinks, coffees, teas, beers, and ales
# 4   Soft drinks, coffees, teas, beers, and ales
# ..                                          ...
# 73                             Seaweed and fish
# 74                             Seaweed and fish
# 75                             Seaweed and fish
# 76                             Seaweed and fish
# 77                                          NaN
#
# [78 rows x 8 columns]

# %%
mask = mrg['CategoryID'].isnull()

# %%
mrg[mask].head()
# Out:
# Empty DataFrame
# Columns: [ProductID, ProductName, UnitPrice, CategoryID, Date1, Date2, CategoryName, Description]
# Index: []

# %%
mask = mrg['ProductID'].isnull()

# %%
mrg[mask].head()

# %%
mrg = pd.merge(products,
               cat)

# %%
mrg
# Out:
#     ProductID                      ProductName  UnitPrice  CategoryID  \
# 0           1                             Chai      18.00           1
# 1           2                            Chang      19.00           1
# 2           3                    Aniseed Syrup      10.00           2
# 3           4     Chef Anton's Cajun Seasoning      22.00           2
# 4           5           Chef Anton's Gumbo Mix      21.35           2
# ..        ...                              ...        ...         ...
# 72         73                       Rad Kaviar      15.00           8
# 73         74                    Longlife Tofu      10.00           7
# 74         75             Rhanbrau Klosterbier       7.75           1
# 75         76                     Lakkalikaari      18.00           1
# 76         77  Original Frankfurter grane Soae      13.00           2
#
#          Date1       Date2 CategoryName  \
# 0   05/12/2022  15/12/2022    Beverages
# 1   06/12/2022  16/12/2022    Beverages
# 2   07/12/2022  17/12/2022   Condiments
# 3   08/12/2022  18/12/2022   Condiments
# 4   09/12/2022  19/12/2022   Condiments
# ..         ...         ...          ...
# 72  27/02/2023  25/02/2023      Seafood
# 73  28/02/2023  26/02/2023      Produce
# 74  01/03/2023  27/02/2023    Beverages
# 75  02/03/2023  28/02/2023    Beverages
# 76  03/03/2023  01/03/2023   Condiments
#
#                                           Description
# 0         Soft drinks, coffees, teas, beers, and ales
# 1         Soft drinks, coffees, teas, beers, and ales
# 2   Sweet and savory sauces, relishes, spreads, an...
# 3   Sweet and savory sauces, relishes, spreads, an...
# 4   Sweet and savory sauces, relishes, spreads, an...
# ..                                                ...
# 72                                   Seaweed and fish
# 73                          Dried fruit and bean curd
# 74        Soft drinks, coffees, teas, beers, and ales
# 75        Soft drinks, coffees, teas, beers, and ales
# 76  Sweet and savory sauces, relishes, spreads, an...
#
# [77 rows x 8 columns]
