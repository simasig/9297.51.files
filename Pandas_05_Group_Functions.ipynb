# %% [markdown]
# # Group Functions
# #sum(),mean(),min(),max(),count()

# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
pup = pd.read_csv("data/pupils.csv")
titanic=sb.load_dataset("titanic")

# %%
pup.head()
# Out:
#    Name  Age Country  Height  Weight  avg  income  rooms  family  type gen
# 0  adar    6      SP     113      30   70   16700      7       6     1   M
# 1  agam    6      GR     172      71   92    9200      5       4     2   F
# 2   avi    7     ISR     143      58   82   12000      3       7     1   M
# 3  dani    7      US     160      70   90   15000      4       4     2   M
# 4  dina    7     ISR     110      26   64   10000      6       8     1   F

# %%
pup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     30 non-null     object
#  1   Age      30 non-null     int64
#  2   Country  30 non-null     object
#  3   Height   30 non-null     int64
#  4   Weight   30 non-null     int64
#  5   avg      30 non-null     int64
#  6   income   30 non-null     int64
#  7   rooms    30 non-null     int64
#  8   family   30 non-null     int64
#  9   type     30 non-null     int64
#  10  gen      30 non-null     object
# dtypes: int64(8), object(3)
# memory usage: 2.7+ KB

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# describe()

# %% [markdown]
# The .describe() function is a useful summarisation tool that will quickly display statistics for any variable or group it is applied to.
# The describe() output varies depending on whether you apply it to a numeric or character column.

# %%
pup.describe()
# Out:
#              Age      Height     Weight        avg        income      rooms  \
# count  30.000000   30.000000  30.000000  30.000000     30.000000  30.000000
# mean    9.433333  137.266667  51.500000  80.500000  20096.666667   4.366667
# std     2.207875   26.286136  18.104581   7.942683  11943.270601   1.629117
# min     6.000000   90.000000  26.000000  64.000000   7600.000000   2.000000
# 25%     8.000000  113.500000  34.000000  74.000000  11175.000000   3.000000
# 50%     9.000000  132.000000  53.000000  82.000000  17650.000000   4.500000
# 75%    11.000000  158.000000  65.500000  85.750000  23750.000000   5.750000
# max    14.000000  192.000000  90.000000  94.000000  54100.000000   7.000000
#
#           family       type
# count  30.000000  30.000000
# mean    5.833333   1.833333
# std     1.743626   0.833908
# min     3.000000   1.000000
# 25%     4.250000   1.000000
# 50%     6.000000   2.000000
# 75%     7.000000   2.750000
# max    10.000000   3.000000

# %%
pup.describe(include=["object"])
# Out:
#         Name Country gen
# count     30      30  30
# unique    29       6   2
# top     orit     ISR   M
# freq       2      10  15

# %%
pup
# Out:
#        Name  Age Country  Height  Weight  avg  income  rooms  family  type gen
# 0      adar    6      SP     113      30   70   16700      7       6     1   M
# 1      agam    6      GR     172      71   92    9200      5       4     2   F
# 2       avi    7     ISR     143      58   82   12000      3       7     1   M
# 3      dani    7      US     160      70   90   15000      4       4     2   M
# 4      dina    7     ISR     110      26   64   10000      6       8     1   F
# 5     efrat    7      EN     115      33   75    8000      5       5     3   F
# 6      ehud    8     ISR     155      66   85   18000      2       7     1   M
# 7       eli    8      GR     155      61   84    8900      7      10     2   M
# 8     ester    8     ISR     130      48   79   19600      2       4     1   F
# 9   evyatar    8     ISR     110      34   72    7600      3       4     1   M
# 10   itamar    8      EN     110      30   71   27000      2       5     2   M
# ...

# %%
#Min method
pup.min()
# Out:
# Name       adar
# Age           6
# Country      EN
# Height       90
# Weight       26
# avg          64
# income     7600
# rooms         2
# family        3
# type          1
# gen           F
# dtype: object

# %%
#Return series
type(pup.min())
# Out:
# pandas.core.series.Series

# %%
pup.sum()
# Out:
# Name       adaragamavidanidinaefratehudeliesterevyatarita...
# Age                                                      283
# Country    SPGRISRUSISRENISRGRISRISRENISRISRGRUSGRSPSPISR...
# Height                                                  4118
# Weight                                                  1545
# avg                                                     2415
# income                                                602900
# rooms                                                    131
# family                                                   175
# type                                                      55
# gen                           MFMMFFMMFMMMFFFMFMMFFFFFFMMFMM
# dtype: object

# %%
pup.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pup.mean()
#
# File C:\Python\Python312\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# File C:\Python\Python312\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
# ...

# %%
#Include only float, int, boolean columns.
pup.sum(numeric_only=True)
# Out:
# Age          283
# Height      4118
# Weight      1545
# avg         2415
# income    602900
# rooms        131
# family       175
# type          55
# dtype: int64

# %%
pup.mean(numeric_only=True)
# Out:
# Age           9.433333
# Height      137.266667
# Weight       51.500000
# avg          80.500000
# income    20096.666667
# rooms         4.366667
# family        5.833333
# type          1.833333
# dtype: float64

# %%
pup.head(5)

# %%
pup.mean(numeric_only=True)
# Out:
# Age           9.433333
# Height      137.266667
# Weight       51.500000
# avg          80.500000
# income    20096.666667
# rooms         4.366667
# family        5.833333
# type          1.833333
# dtype: float64

# %%
pup.income.sum()
# Out:
# np.int64(602900)

# %%
pup["income"].sum()
# Out:
# np.int64(602900)

# %%
pup["Age"].mean()
# Out:
# np.float64(9.433333333333334)

# %%
pup["income"].mean()
# Out:
# np.float64(20096.666666666668)

# %%
pup["income"].std()
# Out:
# np.float64(11943.270600789307)

# %%
pup["type"].count()
# Out:
# np.int64(30)

# %%
#count distinct values
pup["type"].nunique()
# Out:
# 3

# %%
pup.tail(10)
# Out:
#      Name  Age Country  Height  Weight  avg  income  rooms  family  type gen
# 20   orit   10      US     123      40   78   18900      3       7     3   F
# 21   orit   11     ISR     175      73   89   54100      4       3     2   F
# 22   rina   11      EN     100      31   73   30000      2       5     3   F
# 23  shely   11     ISR     148      60   86    8000      4       3     1   F
# 24  talya   12      FR     167      67   89   10900      6       6     2   F
# 25  tomer   12      FR     128      53   82   45000      5       4     3   M
# 26    udi   13      FR     147      55   85   35000      7       6     2   M
# 27  yafit   13      FR     180      90   93   12800      2       4     1   F
# 28   yoav   13      EN     120      36   74   17300      5       8     3   M
# 29   yosi   14      SP     110      32   74   22000      5       6     1   M

# %%
a= pup["Age"]> 10 
b=pup["rooms"]>5

# %%
pup["income"][a&b].mean()
# Out:
# np.float64(22950.0)

# %%
 pup.query("Age>10 and rooms >5")
# Out:
#      Name  Age Country  Height  Weight  avg  income  rooms  family  type gen
# 24  talya   12      FR     167      67   89   10900      6       6     2   F
# 26    udi   13      FR     147      55   85   35000      7       6     2   M

# %%
s=pup.query("Age>10 and rooms >5")

# %%
s
# Out:
#      Name  Age Country  Height  Weight  avg  income  rooms  family  type gen
# 24  talya   12      FR     167      67   89   10900      6       6     2   F
# 26    udi   13      FR     147      55   85   35000      7       6     2   M

# %%
s["income"].mean()
# Out:
# np.float64(22950.0)

# %%
# How many entries are there for each country
pup.Country.value_counts()
# Out:
# Country
# ISR    10
# SP      4
# GR      4
# US      4
# EN      4
# FR      4
# Name: count, dtype: int64

# %%
pup.gen.value_counts()
# Out:
# gen
# M    15
# F    15
# Name: count, dtype: int64

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.sex.value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
titanic ['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
titanic [['sex']].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
titanic [['sex']].value_counts().to_frame()
# Out:
#         count
# sex
# male      577
# female    314

# %% [markdown]
# # Use Pandas Groupby to Group and Summarise DataFrames

# %%
#df.groupby("column")["column/s"].agg_function()

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.count()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %%
titanic.sex.count()
# Out:
# np.int64(891)

# %%
titanic.groupby("sex")

# %%
titanic.groupby("sex").ngroups
# Out:
# 2

# %%
titanic.groupby("sex").groups
# Out:
# {'female': [1, 2, 3, 8, 9, 10, 11, 14, 15, 18, 19, 22, 24, 25, 28, 31, 32, 38, 39, 40, 41, 43, 44, 47, 49, 52, 53, 56, 58, 61, 66, 68, 71, 79, 82, 84, 85, 88, 98, 100, 106, 109, 111, 113, 114, 119, 123, 128, 132, 133, 136, 140, 141, 142, 147, 151, 156, 161, 166, 167, 172, 177, 180, 184, 186, 190, 192, 194, 195, 198, 199, 205, 208, 211, 215, 216, 218, 229, 230, 233, 235, 237, 240, 241, 246, 247, 251, 254, 255, 256, 257, 258, 259, 264, 268, 269, 272, 274, 275, 276, ...], 'male': [0, 4, 5, 6, 7, 12, 13, 16, 17, 20, 21, 23, 26, 27, 29, 30, 33, 34, 35, 36, 37, 42, 45, 46, 48, 50, 51, 54, 55, 57, 59, 60, 62, 63, 64, 65, 67, 69, 70, 72, 73, 74, 75, 76, 77, 78, 80, 81, 83, 86, 87, 89, 90, 91, 92, 93, 94, 95, 96, 97, 99, 101, 102, 103, 104, 105, 107, 108, 110, 112, 115, 116, 117, 118, 120, 121, 122, 124, 125, 126, 127, 129, 130, 131, 134, 135, 137, 138, 139, 143, 144, 145, 146, 148, 149, 150, 152, 153, 154, 155, ...]}

# %%
titanic.groupby("sex").get_group("male")
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.groupby("sex").count()
# Out:
#         survived  pclass  age  sibsp  parch  fare  embarked  class  who  \
# sex
# female       314     314  261    314    314   314       312    314  314
# male         577     577  453    577    577   577       577    577  577
#
#         adult_male  deck  embark_town  alive  alone
# sex
# female         314    97          312    314    314
# male           577   106          577    577    577

# %%
titanic.groupby("sex")[["survived"]].count()
# Out:
#         survived
# sex
# female       314
# male         577

# %%
titanic.groupby("pclass")["fare"].mean()
# Out:
# pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: fare, dtype: float64

# %%
titanic.groupby("pclass")["fare"].sum()
# Out:
# pclass
# 1    18177.4125
# 2     3801.8417
# 3     6714.6951
# Name: fare, dtype: float64

# %%
titanic.groupby("pclass").mean(numeric_only=True)
# Out:
#         survived        age     sibsp     parch       fare  adult_male  \
# pclass
# 1       0.629630  38.233441  0.416667  0.356481  84.154687    0.550926
# 2       0.472826  29.877630  0.402174  0.380435  20.662183    0.538043
# 3       0.242363  25.140620  0.615071  0.393075  13.675550    0.649695
#
#            alone
# pclass
# 1       0.504630
# 2       0.565217
# 3       0.659878

# %%
titanic.groupby("pclass")["fare"].mean()
# Out:
# pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: fare, dtype: float64

# %%
titanic.groupby("pclass").fare.mean()
# Out:
# pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: fare, dtype: float64

# %%
pup
# Out:
#        Name  Age Country  Height  Weight  avg  income  rooms  family  type gen
# 0      adar    6      SP     113      30   70   16700      7       6     1   M
# 1      agam    6      GR     172      71   92    9200      5       4     2   F
# 2       avi    7     ISR     143      58   82   12000      3       7     1   M
# 3      dani    7      US     160      70   90   15000      4       4     2   M
# 4      dina    7     ISR     110      26   64   10000      6       8     1   F
# 5     efrat    7      EN     115      33   75    8000      5       5     3   F
# 6      ehud    8     ISR     155      66   85   18000      2       7     1   M
# 7       eli    8      GR     155      61   84    8900      7      10     2   M
# 8     ester    8     ISR     130      48   79   19600      2       4     1   F
# 9   evyatar    8     ISR     110      34   72    7600      3       4     1   M
# 10   itamar    8      EN     110      30   71   27000      2       5     2   M
# ...

# %%
pup.groupby('Country')

# %%
pup.groupby('Country')['income'].mean()
# Out:
# Country
# EN     20575.0
# FR     25925.0
# GR     18225.0
# ISR    18900.0
# SP     16550.0
# US     22200.0
# Name: income, dtype: float64

# %%
pup.groupby(by='Country').mean(numeric_only=True)
# Out:
#            Age  Height  Weight    avg   income  rooms  family  type
# Country
# EN        9.75  111.25   32.50  73.25  20575.0    3.5    5.75  2.75
# FR       12.50  155.50   66.25  87.25  25925.0    5.0    5.00  2.00
# GR        8.00  146.75   56.00  84.50  18225.0    5.5    6.00  2.50
# ISR       8.70  146.40   57.20  81.80  18900.0    3.5    5.70  1.20
# SP        9.75  105.75   30.75  70.75  16550.0    5.5    6.25  1.00
# US        9.00  144.25   57.75  83.50  22200.0    4.5    6.50  2.50

# %%
pup.groupby('Country')["income"].mean().to_frame()
# Out:
#           income
# Country
# EN       20575.0
# FR       25925.0
# GR       18225.0
# ISR      18900.0
# SP       16550.0
# US       22200.0

# %%
pup.groupby('Country')[["income"]].mean()
# Out:
#           income
# Country
# EN       20575.0
# FR       25925.0
# GR       18225.0
# ISR      18900.0
# SP       16550.0
# US       22200.0

# %%
pup.groupby('Country')[["income","avg"]].mean()
# Out:
#           income    avg
# Country
# EN       20575.0  73.25
# FR       25925.0  87.25
# GR       18225.0  84.50
# ISR      18900.0  81.80
# SP       16550.0  70.75
# US       22200.0  83.50

# %%
df = pup.groupby(['Country'])

# %%
df.income.mean()
# Out:
# Country
# EN     20575.0
# FR     25925.0
# GR     18225.0
# ISR    18900.0
# SP     16550.0
# US     22200.0
# Name: income, dtype: float64

# %%
df["income"].mean()
# Out:
# Country
# EN     20575.0
# FR     25925.0
# GR     18225.0
# ISR    18900.0
# SP     16550.0
# US     22200.0
# Name: income, dtype: float64

# %%
pup.groupby(['Country'])[["income","rooms"]].mean()
# Out:
#           income  rooms
# Country
# EN       20575.0    3.5
# FR       25925.0    5.0
# GR       18225.0    5.5
# ISR      18900.0    3.5
# SP       16550.0    5.5
# US       22200.0    4.5

# %%
df[["income","rooms"]].mean()
# Out:
#           income  rooms
# Country
# EN       20575.0    3.5
# FR       25925.0    5.0
# GR       18225.0    5.5
# ISR      18900.0    3.5
# SP       16550.0    5.5
# US       22200.0    4.5

# %%
pup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     30 non-null     object
#  1   Age      30 non-null     int64
#  2   Country  30 non-null     object
#  3   Height   30 non-null     int64
#  4   Weight   30 non-null     int64
#  5   avg      30 non-null     int64
#  6   income   30 non-null     int64
#  7   rooms    30 non-null     int64
#  8   family   30 non-null     int64
#  9   type     30 non-null     int64
#  10  gen      30 non-null     object
# dtypes: int64(8), object(3)
# memory usage: 2.7+ KB

# %%
pup.groupby('gen')['income'].mean()
# Out:
# gen
# F    19360.000000
# M    20833.333333
# Name: income, dtype: float64

# %%
#select gen, avg(income),avg(room) from pup group by gen
pup.groupby(['gen'])[['income','rooms']].mean()
# Out:
#            income     rooms
# gen
# F    19360.000000  4.333333
# M    20833.333333  4.400000

# %%
pup.groupby(['Country','gen']).income.mean()
# Out:
# Country  gen
# EN       F      19000.0
#          M      22150.0
# FR       F      11850.0
#          M      40000.0
# GR       F      11000.0
#          M      25450.0
# ISR      F      22940.0
#          M      14860.0
# SP       F      18200.0
#          M      16000.0
# US       F      24600.0
#          M      15000.0
# Name: income, dtype: float64

# %%
pup.groupby(['Country','gen']).income.mean().to_frame()
# Out:
#               income
# Country gen
# EN      F    19000.0
#         M    22150.0
# FR      F    11850.0
#         M    40000.0
# GR      F    11000.0
#         M    25450.0
# ISR     F    22940.0
#         M    14860.0
# SP      F    18200.0
#         M    16000.0
# US      F    24600.0
#         M    15000.0

# %%
pup.groupby(['gen','Country']).income.mean().to_frame()
# Out:
#               income
# gen Country
# F   EN       19000.0
#     FR       11850.0
#     GR       11000.0
#     ISR      22940.0
#     SP       18200.0
#     US       24600.0
# M   EN       22150.0
#     FR       40000.0
#     GR       25450.0
#     ISR      14860.0
#     SP       16000.0
#     US       15000.0

# %% [markdown]
# # Groupby Methods

# %%
pup.groupby(['Country']).groups.keys()
# Out:
# dict_keys(['EN', 'FR', 'GR', 'ISR', 'SP', 'US'])

# %%
# Get the first entry for each country
pup.groupby("Country").first()
# Out:
#           Name  Age  Height  Weight  avg  income  rooms  family  type gen
# Country
# EN       efrat    7     115      33   75    8000      5       5     3   F
# FR       talya   12     167      67   89   10900      6       6     2   F
# GR        agam    6     172      71   92    9200      5       4     2   F
# ISR        avi    7     143      58   82   12000      3       7     1   M
# SP        adar    6     113      30   70   16700      7       6     1   M
# US        dani    7     160      70   90   15000      4       4     2   M

# %%
a = pup.groupby('Country')

# %%
a.first()
# Out:
#           Name  Age  Height  Weight  avg  income  rooms  family  type gen
# Country
# EN       efrat    7     115      33   75    8000      5       5     3   F
# FR       talya   12     167      67   89   10900      6       6     2   F
# GR        agam    6     172      71   92    9200      5       4     2   F
# ISR        avi    7     143      58   82   12000      3       7     1   M
# SP        adar    6     113      30   70   16700      7       6     1   M
# US        dani    7     160      70   90   15000      4       4     2   M

# %%
a.last()
# Out:
#           Name  Age  Height  Weight  avg  income  rooms  family  type gen
# Country
# EN        yoav   13     120      36   74   17300      5       8     3   M
# FR       yafit   13     180      90   93   12800      2       4     1   F
# GR       moshe    9     128      43   80   42000      6       5     3   M
# ISR      shely   11     148      60   86    8000      4       3     1   F
# SP        yosi   14     110      32   74   22000      5       6     1   M
# US        orit   10     123      40   78   18900      3       7     3   F

# %%
a.head(2)
# Out:
#       Name  Age Country  Height  Weight  avg  income  rooms  family  type gen
# 0     adar    6      SP     113      30   70   16700      7       6     1   M
# 1     agam    6      GR     172      71   92    9200      5       4     2   F
# 2      avi    7     ISR     143      58   82   12000      3       7     1   M
# 3     dani    7      US     160      70   90   15000      4       4     2   M
# 4     dina    7     ISR     110      26   64   10000      6       8     1   F
# 5    efrat    7      EN     115      33   75    8000      5       5     3   F
# 7      eli    8      GR     155      61   84    8900      7      10     2   M
# 10  itamar    8      EN     110      30   71   27000      2       5     2   M
# 14  michal    9      US     132      53   79   20400      5       7     3   F
# 16    noya    9      SP      90      27   68   18200      6       5     1   F
# 24   talya   12      FR     167      67   89   10900      6       6     2   F
# ...

# %%
type(a)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
#Get number of groups within that object
print ("Number of countries : {} \nNumber of lines : {} ".format(len(a),len(pup)))
# Out:
# Number of countries : 6
# Number of lines : 30

# %%
len(a)
# Out:
# 6

# %%
a.groups.keys()
# Out:
# dict_keys(['EN', 'FR', 'GR', 'ISR', 'SP', 'US'])

# %%
a.get_group("ISR")
# Out:
#        Name  Age Country  Height  Weight  avg  income  rooms  family  type gen
# 2       avi    7     ISR     143      58   82   12000      3       7     1   M
# 4      dina    7     ISR     110      26   64   10000      6       8     1   F
# 6      ehud    8     ISR     155      66   85   18000      2       7     1   M
# 8     ester    8     ISR     130      48   79   19600      2       4     1   F
# 9   evyatar    8     ISR     110      34   72    7600      3       4     1   M
# 11     liel    8     ISR     142      55   84   24000      2       7     1   M
# 12   lilach    9     ISR     192      88   94   23000      5       6     2   F
# 18     ohad   10     ISR     159      64   83   12700      4       8     1   M
# 21     orit   11     ISR     175      73   89   54100      4       3     2   F
# 23    shely   11     ISR     148      60   86    8000      4       3     1   F

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.groupby(["class"]).ngroups
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_5100\2574963758.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   titanic.groupby(["class"]).ngroups
# 3

# %%
titanic.groupby(["class"]).groups
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_5100\1357361582.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   titanic.groupby(["class"]).groups
# ...

# %%
titanic.groupby(["class"]).groups.keys()
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_5100\2895767958.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   titanic.groupby(["class"]).groups.keys()
# dict_keys(['First', 'Second', 'Third'])

# %%
titanic.groupby(["class"]).fare.mean().to_frame()
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_5100\3965923585.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   titanic.groupby(["class"]).fare.mean().to_frame()
#              fare
# class
# First   84.154687
# Second  20.662183
# Third   13.675550

# %%
a

# %%
#The mean income and avg for each country

# %%
a[["income","avg"]].mean()
# Out:
#           income    avg
# Country
# EN       20575.0  73.25
# FR       25925.0  87.25
# GR       18225.0  84.50
# ISR      18900.0  81.80
# SP       16550.0  70.75
# US       22200.0  83.50

# %%
a[["income","avg"]].mean().rename(columns ={"income" : "avg_sal","avg": "avg_score"}).head()
# Out:
#          avg_sal  avg_score
# Country
# EN       20575.0      73.25
# FR       25925.0      87.25
# GR       18225.0      84.50
# ISR      18900.0      81.80
# SP       16550.0      70.75

# %%
a["income"].count().to_frame().head()
# Out:
#          income
# Country
# EN            4
# FR            4
# GR            4
# ISR          10
# SP            4

# %%
b = pup.groupby(['type','Age'])

# %%
b

# %%
pup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     30 non-null     object
#  1   Age      30 non-null     int64
#  2   Country  30 non-null     object
#  3   Height   30 non-null     int64
#  4   Weight   30 non-null     int64
#  5   avg      30 non-null     int64
#  6   income   30 non-null     int64
#  7   rooms    30 non-null     int64
#  8   family   30 non-null     int64
#  9   type     30 non-null     int64
#  10  gen      30 non-null     object
# dtypes: int64(8), object(3)
# memory usage: 2.7+ KB

# %%
b.mean(numeric_only=True)
# Out:
#               Height     Weight        avg        income  rooms    family
# type Age
# 1    6    113.000000  30.000000  70.000000  16700.000000   7.00  6.000000
#      7    126.500000  42.000000  73.000000  11000.000000   4.50  7.500000
#      8    134.250000  50.750000  80.000000  17300.000000   2.25  5.500000
#      9     90.000000  27.000000  68.000000  18200.000000   6.00  5.000000
#      10   134.500000  49.000000  77.000000  11000.000000   4.00  8.000000
#      11   148.000000  60.000000  86.000000   8000.000000   4.00  3.000000
#      13   180.000000  90.000000  93.000000  12800.000000   2.00  4.000000
#      14   110.000000  32.000000  74.000000  22000.000000   5.00  6.000000
# 2    6    172.000000  71.000000  92.000000   9200.000000   5.00  4.000000
#      7    160.000000  70.000000  90.000000  15000.000000   4.00  4.000000
#      8    132.500000  45.500000  77.500000  17950.000000   4.50  7.500000
#      9    192.000000  88.000000  94.000000  23000.000000   5.00  6.000000
# ...

# %%
pup.groupby(['Age','type']).income.mean()
# Out:
# Age  type
# 6    1       16700.000000
#      2        9200.000000
# 7    1       11000.000000
#      2       15000.000000
#      3        8000.000000
# 8    1       17300.000000
#      2       17950.000000
# 9    1       18200.000000
#      2       23000.000000
#      3       25066.666667
# 10   1       11000.000000
#      2       34500.000000
#      3       18900.000000
# 11   1        8000.000000
#      2       54100.000000
#      3       30000.000000
# 12   2       10900.000000
#      3       45000.000000
# 13   1       12800.000000
#      2       35000.000000
#      3       17300.000000
# 14   1       22000.000000
# Name: income, dtype: float64

# %%
pup.sort_values(['type','Age'],ascending=True)
# Out:
#        Name  Age Country  Height  Weight  avg  income  rooms  family  type gen
# 0      adar    6      SP     113      30   70   16700      7       6     1   M
# 2       avi    7     ISR     143      58   82   12000      3       7     1   M
# 4      dina    7     ISR     110      26   64   10000      6       8     1   F
# 6      ehud    8     ISR     155      66   85   18000      2       7     1   M
# 8     ester    8     ISR     130      48   79   19600      2       4     1   F
# 9   evyatar    8     ISR     110      34   72    7600      3       4     1   M
# 11     liel    8     ISR     142      55   84   24000      2       7     1   M
# 16     noya    9      SP      90      27   68   18200      6       5     1   F
# 17     ofer   10      SP     110      34   71    9300      4       8     1   M
# 18     ohad   10     ISR     159      64   83   12700      4       8     1   M
# 23    shely   11     ISR     148      60   86    8000      4       3     1   F
# ...

# %%
a = pup.groupby('Country')

# %%
a[["Age","income"]].mean()
# Out:
#            Age   income
# Country
# EN        9.75  20575.0
# FR       12.50  25925.0
# GR        8.00  18225.0
# ISR       8.70  18900.0
# SP        9.75  16550.0
# US        9.00  22200.0

# %%
a.corr(numeric_only=True)
# Out:
#                          Age    Height    Weight       avg    income  \
# Country
# EN      Age     1.000000e+00  0.088596  0.571886  0.088596  0.296770
#         Height  8.859624e-02  1.000000  0.774597  0.428571 -0.742475
#         Weight  5.718863e-01  0.774597  1.000000  0.700826 -0.605155
#         avg     8.859624e-02  0.428571  0.700826  1.000000 -0.806995
#         income  2.967700e-01 -0.742475 -0.605155 -0.806995  1.000000
#         rooms   1.048285e-01  0.845154  0.872872  0.845154 -0.916679
#         family  7.867958e-01  0.683130  0.881917  0.292770 -0.218710
#         type    4.236593e-01  0.097590  0.629941  0.878310 -0.429072
# FR      Age     1.000000e+00  0.404966  0.424583  0.422116 -0.139388
#         Height  4.049660e-01  1.000000  0.903125  0.990551 -0.954771
#         Weight  4.245835e-01  0.903125  1.000000  0.953469 -0.792394
#         avg     4.221159e-01  0.990551  0.953469  1.000000 -0.922831
# ...

# %% [markdown]
# # Pandas DataFrame agg() Method

# %% [markdown]
# #Pandas Series.agg() is used to pass a function or list of function to be applied on a series or even each element of series separately.

# %%
pup.groupby("Country")[["income"]].mean()
# Out:
#           income
# Country
# EN       20575.0
# FR       25925.0
# GR       18225.0
# ISR      18900.0
# SP       16550.0
# US       22200.0

# %%
pup.groupby("Country")[["income"]].agg("mean")
# Out:
#           income
# Country
# EN       20575.0
# FR       25925.0
# GR       18225.0
# ISR      18900.0
# SP       16550.0
# US       22200.0

# %%
pup.groupby("Country")[["income"]].agg(["mean","count","median"])
# Out:
#           income
#             mean count   median
# Country
# EN       20575.0     4  22150.0
# FR       25925.0     4  23900.0
# GR       18225.0     4  11000.0
# ISR      18900.0    10  15350.0
# SP       16550.0     4  17450.0
# US       22200.0     4  19650.0

# %%
pup.agg('count').to_frame()
# Out:
#           0
# Name     30
# Age      30
# Country  30
# Height   30
# Weight   30
# avg      30
# income   30
# rooms    30
# family   30
# type     30
# gen      30

# %%
pup.agg(['count','min'])
# Out:
#        Name  Age Country  Height  Weight  avg  income  rooms  family  type gen
# count    30   30      30      30      30   30      30     30      30    30  30
# min    adar    6      EN      90      26   64    7600      2       3     1   F

# %%
pup.groupby("Country").agg(['count','max'])
# Out:
#          Name          Age     Height      Weight       avg     income         \
#         count    max count max  count  max  count max count max  count    max
# Country
# EN          4   yoav     4  13      4  120      4  36     4  75      4  30000
# FR          4  yafit     4  13      4  180      4  90     4  93      4  45000
# GR          4  moshe     4   9      4  172      4  71     4  92      4  42000
# ISR        10  shely    10  11     10  192     10  88    10  94     10  54100
# SP          4   yosi     4  14      4  113      4  34     4  74      4  22000
# US          4   orit     4  10      4  162      4  70     4  90      4  34500
#
#         rooms     family      type       gen
#         count max  count max count max count max
# Country
# EN          4   5      4   8     4   3     4   M
# FR          4   7      4   6     4   3     4   M
# GR          4   7      4  10     4   3     4   M
# ISR        10   6     10   8    10   2    10   M
# ...

# %%
#Different aggrigation per column

# %%
pup.groupby("Country").agg({'Name':'count','income':['sum','mean','max'],'Age':'max','rooms':'mean'})
# Out:
#          Name  income                 Age rooms
#         count     sum     mean    max max  mean
# Country
# EN          4   82300  20575.0  30000  13   3.5
# FR          4  103700  25925.0  45000  13   5.0
# GR          4   72900  18225.0  42000   9   5.5
# ISR        10  189000  18900.0  54100  11   3.5
# SP          4   66200  16550.0  22000  14   5.5
# US          4   88800  22200.0  34500  10   4.5

# %%
pup.groupby("Country").agg(
                        count_name=('Name','count'),
                        mean_income=('income','mean'),
                        max_age = ('Age','max'))
# Out:
#          count_name  mean_income  max_age
# Country
# EN                4      20575.0       13
# FR                4      25925.0       13
# GR                4      18225.0        9
# ISR              10      18900.0       11
# SP                4      16550.0       14
# US                4      22200.0       10

# %% [markdown]
# ### Multiple index

# %%
pup.head()

# %%
g1=pup.groupby("Country")["avg"].mean()

# %%
g1.index
# Out:
# Index(['EN', 'FR', 'GR', 'ISR', 'SP', 'US'], dtype='object', name='Country')

# %%
df=pup.groupby(["Country","gen"])["avg"].mean()

# %%
df
# Out:
# Country  gen
# EN       F      74.000000
#          M      72.500000
# FR       F      91.000000
#          M      83.500000
# GR       F      87.000000
#          M      82.000000
# ISR      F      82.400000
#          M      81.200000
# SP       F      68.000000
#          M      71.666667
# US       F      81.333333
#          M      90.000000
# Name: avg, dtype: float64

# %% [markdown]
# #

# %%
df=pup.groupby(["Country","gen"]).mean(numeric_only=True)

# %%
df.head()
# Out:
#               Age  Height  Weight   avg   income  rooms  family  type
# Country gen
# EN      F     9.0   107.5    32.0  74.0  19000.0    3.5     5.0   3.0
#         M    10.5   115.0    33.0  72.5  22150.0    3.5     6.5   2.5
# FR      F    12.5   173.5    78.5  91.0  11850.0    4.0     5.0   1.5
#         M    12.5   137.5    54.0  83.5  40000.0    6.0     5.0   2.5
# GR      F     7.5   152.0    60.0  87.0  11000.0    4.5     4.5   2.5

# %%
df.index
# Out:
# MultiIndex([( 'EN', 'F'),
#             ( 'EN', 'M'),
#             ( 'FR', 'F'),
#             ( 'FR', 'M'),
#             ( 'GR', 'F'),
#             ( 'GR', 'M'),
#             ('ISR', 'F'),
#             ('ISR', 'M'),
#             ( 'SP', 'F'),
#             ( 'SP', 'M'),
#             ( 'US', 'F'),
#             ( 'US', 'M')],
#            names=['Country', 'gen'])
